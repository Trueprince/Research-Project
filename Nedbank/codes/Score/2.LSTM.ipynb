# %% [markdown]
# ## ***Load Libraries***

# %%
# %pip install lime
# Out:
# Requirement already satisfied: lime in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (3.9.2)
# Requirement already satisfied: numpy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.14.0)
# Requirement already satisfied: tqdm in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.5.1)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (0.24.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (2024.8.30)
# Requirement already satisfied: packaging>=21 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from scikit-image>=0.12->lime) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tqdm->lime) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (0.46.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.14.0)
# Requirement already satisfied: scikit-learn in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (2.7.1)
# Requirement already satisfied: filelock in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (75.8.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\202207760\appdata\roaming\python\python312\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\202207760\appdata\roaming\python\python312\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (4.52.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: filelock in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.8.30)

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (2.7.1)
# Requirement already satisfied: filelock in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch) (75.8.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip uninstall keras
#!pip install keras==2.11

# %%
# %pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in c:\users\202207760\appdata\roaming\python\python312\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.66.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.8.1)
# Requirement already satisfied: namex in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install lime
# Out:
# Requirement already satisfied: lime in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (3.9.2)
# Requirement already satisfied: numpy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.14.0)
# Requirement already satisfied: tqdm in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (1.5.1)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from lime) (0.24.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (2024.8.30)
# Requirement already satisfied: packaging>=21 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from scikit-image>=0.12->lime) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tqdm->lime) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\202207760\appdata\roaming\python\python312\site-packages (from keras-tuner) (3.10.0)
# Requirement already satisfied: packaging in c:\users\202207760\appdata\roaming\python\python312\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (2.2.2)
# Requirement already satisfied: numpy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (13.8.1)
# Requirement already satisfied: namex in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from keras->keras-tuner) (0.5.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->keras-tuner) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\202207760\appdata\roaming\python\python312\site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import re
nltk.download('punkt_tab')
import pandas as pd
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from transformers import BertTokenizer, BertModel
import torch
from sklearn.decomposition import LatentDirichletAllocation, PCA
from sklearn.feature_extraction.text import CountVectorizer
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
from tqdm.notebook import tqdm
from tensorflow.keras.models import load_model
from lime.lime_text import LimeTextExplainer
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
from collections import Counter
import plotly.express as px
from plotly import colors
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow.keras.layers import GRU, Dropout, Dense
import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\202207760\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\202207760\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\202207760\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# WARNING:tensorflow:From c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## ***Load Dataset***

# %%
# Folder path
folder_path = r'C:\Users\202207760\OneDrive - Sol Plaatje University\Desktop\Nedbank\data'

# %%
# -----------------------------
# .Capitec
# -----------------------------
df = pd.read_csv(os.path.join(folder_path, 'nedbank_reviews.csv'), parse_dates=['at', 'repliedAt'])
print("Capitec:", df.shape)
# Out:
# Capitec: (35016, 11)

# %%
df.head()
# Out:
#                                reviewId                 userName  \
# 0  05b5f11a-0960-4337-aabc-ad23736f2f19             Marumo Mokon
# 1  923cd3b1-7661-4eac-8318-f5976f9bc43c               Jason Louw
# 2  9b535cf5-f801-4b1a-9849-a82cf330790e      Patrick Songambandu
# 3  7bdc1847-1ea7-44a5-9e4b-afc110c0dfb0  Molwantwa James Kubheka
# 4  70406f94-f236-4dff-88fd-6fa29e8f130c             Mpho Maubane
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                    I like this app      5              0
# 1  Very good.just that nedbank is now getting to ...      5              0
# 2                          Struggling to do anything      1              0
# 3                     I need to download nedbank app      5              0
# 4                                     Great security      5              0
#
#   reviewCreatedVersion                  at  \
# 0         9.4.1-0-prod 2024-12-31 21:25:53
# 1         9.4.3-0-prod 2024-12-31 17:29:04
# 2         9.4.3-0-prod 2024-12-31 14:53:36
# 3                  NaN 2024-12-31 14:31:28
# 4         9.4.3-0-prod 2024-12-31 14:11:00
#
#                                         replyContent           repliedAt  \
# 0  We’re pleased that you’re enjoying the app. Th... 2025-01-03 08:10:31
# 1  We’re glad that you like the Money app. Your s... 2025-01-03 08:10:12
# 2  Thank you for the feedback. We don’t fully und... 2025-01-03 08:44:29
# 3  Thank you for the positive review. If you need... 2025-01-03 08:09:31
# 4  That’s what we’re aiming for! Thank you for th... 2025-01-03 08:08:32
#
#      appVersion
# 0  9.4.1-0-prod
# 1  9.4.3-0-prod
# 2  9.4.3-0-prod
# 3           NaN
# 4  9.4.3-0-prod

# %% [markdown]
# # ***EDA***

# %%
# Display summary information about the dataset
print("\nSummary information about the dataset:")
print(df.info())
# Out:
# Summary information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35016 entries, 0 to 35015
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              35016 non-null  object
#  1   userName              35016 non-null  object
#  2   userImage             35016 non-null  object
#  3   content               35006 non-null  object
#  4   score                 35016 non-null  int64
#  5   thumbsUpCount         35016 non-null  int64
#  6   reviewCreatedVersion  29697 non-null  object
#  7   at                    35016 non-null  datetime64[ns]
#  8   replyContent          34869 non-null  object
#  9   repliedAt             34869 non-null  datetime64[ns]
#  10  appVersion            29697 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.9+ MB
# None

# %%
# statistics for numerical columns
print("\nBasic statistics for numerical columns:")
df.describe()
# Out:
# Basic statistics for numerical columns:
#               score  thumbsUpCount                             at  \
# count  35016.000000   35016.000000                          35016
# mean       3.912126       2.209276  2021-02-17 13:26:18.630169088
# min        1.000000       0.000000            2017-10-16 07:25:15
# 25%        3.000000       0.000000     2020-01-08 21:21:48.500000
# 50%        5.000000       0.000000            2021-01-22 07:11:53
# 75%        5.000000       0.000000  2022-04-27 09:40:11.750000128
# max        5.000000    3521.000000            2024-12-31 21:25:53
# std        1.611793      35.420559                            NaN
#
#                            repliedAt
# count                          34869
# mean   2021-02-12 06:45:44.563939328
# min              2017-11-04 10:40:21
# 25%              2019-12-20 14:22:19
# 50%              2021-01-21 14:11:21
# 75%              2022-04-26 12:41:52
# max              2025-01-03 08:44:29
# std                              NaN

# %%
# Check for missing values
print("\nMissing values in each column:")
df.isnull().sum()
# Out:
# Missing values in each column:
# reviewId                   0
# userName                   0
# userImage                  0
# content                   10
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    5319
# at                         0
# replyContent             147
# repliedAt                147
# appVersion              5319
# dtype: int64

# %%
# Display the distribution of scores
print("\nDistribution of scores:")
df['score'].value_counts()
# Out:
# Distribution of scores:
# score
# 5    21977
# 1     6920
# 4     3167
# 3     1610
# 2     1342
# Name: count, dtype: int64

# %%
# Display the distribution of thumbs up count
print("\nDistribution of thumbs up count:")
df['thumbsUpCount'].value_counts()
# Out:
# Distribution of thumbs up count:
# thumbsUpCount
# 0      28653
# 1       3032
# 2        983
# 3        548
# 4        351
#        ...
# 152        1
# 94         1
# 188        1
# 144        1
# 486        1
# Name: count, Length: 209, dtype: int64

# %%
# Overall reviews over time
df['at'].dt.to_period('M').value_counts().sort_index().plot(kind='line', figsize=(12, 6))
plt.title('Number of Reviews Over Time (Monthly) for Capitec bank')
plt.xlabel('Month')
plt.ylabel('Number of Reviews')
plt.show()

# %%
# Count reviews per score
counts = (
    df.groupby('score')
    .size()
    .reset_index(name='count')
)

# Sort and plot
counts = counts.sort_values('score')

plt.figure(figsize=(10, 6))
sns.barplot(
    data=counts,
    x='score',
    y='count',
    order=[1, 2, 3, 4, 5]
)

plt.title('Ratings Distribution - Capitec bank')
plt.xlabel('Score')
plt.ylabel('Number of Reviews')
plt.show()

# %%
# Overall Word Cloud
all_text = " ".join(df['content'].dropna().astype(str))

wordcloud_all = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud_all, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Capitec bank')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='score', y='thumbsUpCount')
plt.title('Distribution of Thumbs Up Count by Rating Score for Capitec bank ')
plt.xlabel('Score')
plt.ylabel('Thumbs Up Count')
plt.show()

# %%
# Add reply flag
df['has_reply'] = df['replyContent'].notnull()

# Group by score only (no Bank_Name)
reply_rate_by_score = (
    df.groupby('score')['has_reply']
    .mean()
    .reset_index()
)

#  Sort by score
reply_rate_by_score = reply_rate_by_score.sort_values('score')

#  Plot: simple bar plot, no hue needed
plt.figure(figsize=(10, 6))
sns.barplot(
    data=reply_rate_by_score,
    x='score',
    y='has_reply',
    order=[1, 2, 3, 4, 5]
)

# Labels & title
plt.xlabel("Score")
plt.ylabel("Reply Rate")
plt.title("Reply Rate by Score - Capitec bank")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# # ***Data Cleaning and Preprocessing***

# %%
# Drop rows where review text is missing
df = df.dropna(subset=['content']).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35006 entries, 0 to 35005
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              35006 non-null  object
#  1   userName              35006 non-null  object
#  2   userImage             35006 non-null  object
#  3   content               35006 non-null  object
#  4   score                 35006 non-null  int64
#  5   thumbsUpCount         35006 non-null  int64
#  6   reviewCreatedVersion  29689 non-null  object
#  7   at                    35006 non-null  datetime64[ns]
#  8   replyContent          34859 non-null  object
#  9   repliedAt             34859 non-null  datetime64[ns]
#  10  appVersion            29689 non-null  object
#  11  has_reply             35006 non-null  bool
# dtypes: bool(1), datetime64[ns](2), int64(2), object(7)
# memory usage: 3.0+ MB

# %%
# ================================================
#  STEP 2: Keep useful columns
# ================================================
# Example: using your combined_df
columns_to_keep = ['content', 'score', 'at','thumbsUpCount', 'appVersion']
df = df[columns_to_keep].copy()

# %%
# Fill missing appVersion with 'unknown'
df['appVersion'] = df['appVersion'].fillna('unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35006 entries, 0 to 35005
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        35006 non-null  object
#  1   score          35006 non-null  int64
#  2   at             35006 non-null  datetime64[ns]
#  3   thumbsUpCount  35006 non-null  int64
#  4   appVersion     35006 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# ## **FEATURE ENGINEERING**

# %%
def label_sentiment(score):
    if score <= 2:
        return 'negative'
    elif score == 3:
        return 'neutral'
    else:
        return 'positive'

# Apply the function to create a new 'sentiment' column
df['sentiment'] = df['score'].apply(label_sentiment)

# Print the value counts of the 'sentiment' column
print(df['sentiment'].value_counts())
# Out:
# sentiment
# positive    25137
# negative     8261
# neutral      1608
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35006 entries, 0 to 35005
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        35006 non-null  object
#  1   score          35006 non-null  int64
#  2   at             35006 non-null  datetime64[ns]
#  3   thumbsUpCount  35006 non-null  int64
#  4   appVersion     35006 non-null  object
#  5   sentiment      35006 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#                                              content  score  \
# 0                                    I like this app      5
# 1  Very good.just that nedbank is now getting to ...      5
# 2                          Struggling to do anything      1
# 3                     I need to download nedbank app      5
# 4                                     Great security      5
#
#                    at  thumbsUpCount    appVersion sentiment
# 0 2024-12-31 21:25:53              0  9.4.1-0-prod  positive
# 1 2024-12-31 17:29:04              0  9.4.3-0-prod  positive
# 2 2024-12-31 14:53:36              0  9.4.3-0-prod  negative
# 3 2024-12-31 14:31:28              0       unknown  positive
# 4 2024-12-31 14:11:00              0  9.4.3-0-prod  positive

# %%
temp = df.groupby('sentiment').count()['content'].reset_index().sort_values(by='content',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_fee46_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_fee46_row1_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fee46_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_fee46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fee46_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_fee46_level0_col1" class="col_heading level0 col1" >content</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fee46_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_fee46_row0_col0" class="data row0 col0" >positive</td>
#       <td id="T_fee46_row0_col1" class="data row0 col1" >25137</td>
#     </tr>
#     <tr>
#       <th id="T_fee46_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_fee46_row1_col0" class="data row1 col0" >negative</td>
#       <td id="T_fee46_row1_col1" class="data row1 col1" >8261</td>
#     </tr>
#     <tr>
#       <th id="T_fee46_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_fee46_row2_col0" class="data row2 col0" >neutral</td>
#       <td id="T_fee46_row2_col1" class="data row2 col1" >1608</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=df)
plt.show()

# %%
# %pip install contractions
# Out:
# Requirement already satisfied: contractions in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.3)
# Requirement already satisfied: pyahocorasick in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from textsearch>=0.0.21->contractions) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# =========================
import re
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import contractions
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# =========================
#  TEXT CLEANING FUNCTION
# =========================
stop_words = set(stopwords.words('english')) - {'no', 'not'}
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # Expand contractions
    text = contractions.fix(text)
    text = text.lower()
    
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    
    # Remove non-letters (keep alphabet and space)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Tokenize
    tokens = word_tokenize(text)
    
    # Remove stopwords (preserving negations) + lemmatize
    tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    
    return ' '.join(tokens)

df['clean_content'] = df['content'].apply(clean_text)

# %%
df.head()
# Out:
#                                              content  score  \
# 0                                    I like this app      5
# 1  Very good.just that nedbank is now getting to ...      5
# 2                          Struggling to do anything      1
# 3                     I need to download nedbank app      5
# 4                                     Great security      5
#
#                    at  thumbsUpCount    appVersion sentiment  \
# 0 2024-12-31 21:25:53              0  9.4.1-0-prod  positive
# 1 2024-12-31 17:29:04              0  9.4.3-0-prod  positive
# 2 2024-12-31 14:53:36              0  9.4.3-0-prod  negative
# 3 2024-12-31 14:31:28              0       unknown  positive
# 4 2024-12-31 14:11:00              0  9.4.3-0-prod  positive
#
#                         clean_content
# 0                            like app
# 1  goodjust nedbank getting expensive
# 2                 struggling anything
# 3           need download nedbank app
# 4                      great security

# %% [markdown]
# # **Insightful Visualization**

# %%
df['temp_list'] = df['clean_content'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_09f13_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_09f13_row1_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_09f13_row2_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_09f13_row3_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_09f13_row4_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_09f13_row5_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_09f13_row6_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_09f13_row7_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_09f13_row8_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_09f13_row9_col1, #T_09f13_row10_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_09f13_row11_col1, #T_09f13_row12_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_09f13_row13_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_09f13_row14_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_09f13_row15_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_09f13_row16_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_09f13_row17_col1, #T_09f13_row18_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_09f13_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_09f13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09f13_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_09f13_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09f13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09f13_row0_col0" class="data row0 col0" >app</td>
#       <td id="T_09f13_row0_col1" class="data row0 col1" >15825</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09f13_row1_col0" class="data row1 col0" >not</td>
#       <td id="T_09f13_row1_col1" class="data row1 col1" >9243</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09f13_row2_col0" class="data row2 col0" >good</td>
#       <td id="T_09f13_row2_col1" class="data row2 col1" >5193</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09f13_row3_col0" class="data row3 col0" >easy</td>
#       <td id="T_09f13_row3_col1" class="data row3 col1" >3665</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09f13_row4_col0" class="data row4 col0" >use</td>
#       <td id="T_09f13_row4_col1" class="data row4 col1" >3395</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_09f13_row5_col0" class="data row5 col0" >nedbank</td>
#       <td id="T_09f13_row5_col1" class="data row5 col1" >3325</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_09f13_row6_col0" class="data row6 col0" >great</td>
#       <td id="T_09f13_row6_col1" class="data row6 col1" >2507</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_09f13_row7_col0" class="data row7 col0" >bank</td>
#       <td id="T_09f13_row7_col1" class="data row7 col1" >2367</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_09f13_row8_col0" class="data row8 col0" >excellent</td>
#       <td id="T_09f13_row8_col1" class="data row8 col1" >2163</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_09f13_row9_col0" class="data row9 col0" >money</td>
#       <td id="T_09f13_row9_col1" class="data row9 col1" >2063</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_09f13_row10_col0" class="data row10 col0" >time</td>
#       <td id="T_09f13_row10_col1" class="data row10 col1" >2042</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_09f13_row11_col0" class="data row11 col0" >best</td>
#       <td id="T_09f13_row11_col1" class="data row11 col1" >1823</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_09f13_row12_col0" class="data row12 col0" >banking</td>
#       <td id="T_09f13_row12_col1" class="data row12 col1" >1804</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_09f13_row13_col0" class="data row13 col0" >love</td>
#       <td id="T_09f13_row13_col1" class="data row13 col1" >1706</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_09f13_row14_col0" class="data row14 col0" >no</td>
#       <td id="T_09f13_row14_col1" class="data row14 col1" >1616</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_09f13_row15_col0" class="data row15 col0" >account</td>
#       <td id="T_09f13_row15_col1" class="data row15 col1" >1576</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_09f13_row16_col0" class="data row16 col0" >work</td>
#       <td id="T_09f13_row16_col1" class="data row16 col1" >1506</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_09f13_row17_col0" class="data row17 col0" >update</td>
#       <td id="T_09f13_row17_col1" class="data row17 col1" >1454</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_09f13_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_09f13_row18_col1" class="data row18 col1" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_09f13_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_09f13_row19_col0" class="data row19 col0" >make</td>
#       <td id="T_09f13_row19_col1" class="data row19 col1" >1373</td>
#     </tr>
#   </tbody>
# </table>

# %%
pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (306)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_22152_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_22152_row1_col1 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_22152_row2_col1 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_22152_row3_col1 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_22152_row4_col1 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_22152_row5_col1 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_22152_row6_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_22152_row7_col1 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_22152_row8_col1 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_22152_row9_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_22152_row10_col1 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_22152_row11_col1 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_22152_row12_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_22152_row13_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_22152_row14_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_22152_row15_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_22152_row16_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_22152_row17_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_22152_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_22152">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22152_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_22152_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22152_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_22152_row0_col0" class="data row0 col0" >good</td>
#       <td id="T_22152_row0_col1" class="data row0 col1" >5193</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_22152_row1_col0" class="data row1 col0" >easy</td>
#       <td id="T_22152_row1_col1" class="data row1 col1" >3665</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_22152_row2_col0" class="data row2 col0" >use</td>
#       <td id="T_22152_row2_col1" class="data row2 col1" >3395</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_22152_row3_col0" class="data row3 col0" >nedbank</td>
#       <td id="T_22152_row3_col1" class="data row3 col1" >3325</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_22152_row4_col0" class="data row4 col0" >great</td>
#       <td id="T_22152_row4_col1" class="data row4 col1" >2507</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_22152_row5_col0" class="data row5 col0" >bank</td>
#       <td id="T_22152_row5_col1" class="data row5 col1" >2367</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_22152_row6_col0" class="data row6 col0" >excellent</td>
#       <td id="T_22152_row6_col1" class="data row6 col1" >2163</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_22152_row7_col0" class="data row7 col0" >money</td>
#       <td id="T_22152_row7_col1" class="data row7 col1" >2063</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_22152_row8_col0" class="data row8 col0" >time</td>
#       <td id="T_22152_row8_col1" class="data row8 col1" >2042</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_22152_row9_col0" class="data row9 col0" >best</td>
#       <td id="T_22152_row9_col1" class="data row9 col1" >1823</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_22152_row10_col0" class="data row10 col0" >banking</td>
#       <td id="T_22152_row10_col1" class="data row10 col1" >1804</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_22152_row11_col0" class="data row11 col0" >love</td>
#       <td id="T_22152_row11_col1" class="data row11 col1" >1706</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_22152_row12_col0" class="data row12 col0" >account</td>
#       <td id="T_22152_row12_col1" class="data row12 col1" >1576</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_22152_row13_col0" class="data row13 col0" >work</td>
#       <td id="T_22152_row13_col1" class="data row13 col1" >1506</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_22152_row14_col0" class="data row14 col0" >update</td>
#       <td id="T_22152_row14_col1" class="data row14 col1" >1454</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_22152_row15_col0" class="data row15 col0" >need</td>
#       <td id="T_22152_row15_col1" class="data row15 col1" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_22152_row16_col0" class="data row16 col0" >make</td>
#       <td id="T_22152_row16_col1" class="data row16 col1" >1373</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_22152_row17_col0" class="data row17 col0" >like</td>
#       <td id="T_22152_row17_col1" class="data row17 col1" >1273</td>
#     </tr>
#     <tr>
#       <th id="T_22152_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_22152_row18_col0" class="data row18 col0" >even</td>
#       <td id="T_22152_row18_col1" class="data row18 col1" >1224</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Most Common words in Text**

# %%
df['temp_list1'] = df['content'].apply(lambda x:str(x).split())
df['temp_list1'] = df['temp_list1'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df['temp_list1'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2efa7_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2efa7_row1_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_2efa7_row2_col1, #T_2efa7_row3_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_2efa7_row4_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_2efa7_row5_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_2efa7_row6_col1, #T_2efa7_row7_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_2efa7_row8_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_2efa7_row9_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_2efa7_row10_col1, #T_2efa7_row11_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_2efa7_row12_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_2efa7_row13_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_2efa7_row14_col1, #T_2efa7_row15_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2efa7_row16_col1, #T_2efa7_row17_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2efa7_row18_col1, #T_2efa7_row19_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2efa7_row20_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2efa7_row21_col1, #T_2efa7_row22_col1, #T_2efa7_row23_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_2efa7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2efa7_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_2efa7_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2efa7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2efa7_row0_col0" class="data row0 col0" >app</td>
#       <td id="T_2efa7_row0_col1" class="data row0 col1" >11240</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2efa7_row1_col0" class="data row1 col0" >use</td>
#       <td id="T_2efa7_row1_col1" class="data row1 col1" >2710</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2efa7_row2_col0" class="data row2 col0" >Good</td>
#       <td id="T_2efa7_row2_col1" class="data row2 col1" >2588</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2efa7_row3_col0" class="data row3 col0" >easy</td>
#       <td id="T_2efa7_row3_col1" class="data row3 col1" >2587</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2efa7_row4_col0" class="data row4 col0" >good</td>
#       <td id="T_2efa7_row4_col1" class="data row4 col1" >2371</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2efa7_row5_col0" class="data row5 col0" >Nedbank</td>
#       <td id="T_2efa7_row5_col1" class="data row5 col1" >1969</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2efa7_row6_col0" class="data row6 col0" >Very</td>
#       <td id="T_2efa7_row6_col1" class="data row6 col1" >1942</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2efa7_row7_col0" class="data row7 col0" >The</td>
#       <td id="T_2efa7_row7_col1" class="data row7 col1" >1925</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2efa7_row8_col0" class="data row8 col0" >This</td>
#       <td id="T_2efa7_row8_col1" class="data row8 col1" >1794</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_2efa7_row9_col0" class="data row9 col0" >It</td>
#       <td id="T_2efa7_row9_col1" class="data row9 col1" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_2efa7_row10_col0" class="data row10 col0" >Excellent</td>
#       <td id="T_2efa7_row10_col1" class="data row10 col1" >1740</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_2efa7_row11_col0" class="data row11 col0" >bank</td>
#       <td id="T_2efa7_row11_col1" class="data row11 col1" >1717</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_2efa7_row12_col0" class="data row12 col0" >money</td>
#       <td id="T_2efa7_row12_col1" class="data row12 col1" >1635</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_2efa7_row13_col0" class="data row13 col0" >can't</td>
#       <td id="T_2efa7_row13_col1" class="data row13 col1" >1514</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_2efa7_row14_col0" class="data row14 col0" >banking</td>
#       <td id="T_2efa7_row14_col1" class="data row14 col1" >1477</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_2efa7_row15_col0" class="data row15 col0" >app.</td>
#       <td id="T_2efa7_row15_col1" class="data row15 col1" >1476</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_2efa7_row16_col0" class="data row16 col0" >Great</td>
#       <td id="T_2efa7_row16_col1" class="data row16 col1" >1451</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_2efa7_row17_col0" class="data row17 col0" >App</td>
#       <td id="T_2efa7_row17_col1" class="data row17 col1" >1434</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_2efa7_row18_col0" class="data row18 col0" >love</td>
#       <td id="T_2efa7_row18_col1" class="data row18 col1" >1216</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_2efa7_row19_col0" class="data row19 col0" >time</td>
#       <td id="T_2efa7_row19_col1" class="data row19 col1" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_2efa7_row20_col0" class="data row20 col0" >like</td>
#       <td id="T_2efa7_row20_col1" class="data row20 col1" >1174</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_2efa7_row21_col0" class="data row21 col0" >It's</td>
#       <td id="T_2efa7_row21_col1" class="data row21 col1" >1134</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_2efa7_row22_col0" class="data row22 col0" >even</td>
#       <td id="T_2efa7_row22_col1" class="data row22 col1" >1122</td>
#     </tr>
#     <tr>
#       <th id="T_2efa7_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_2efa7_row23_col0" class="data row23 col0" >get</td>
#       <td id="T_2efa7_row23_col1" class="data row23 col1" >1113</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Text', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()

# %% [markdown]
# ## **Most common words Sentiments Wise**

# %%
Positive_sent = df[df['sentiment']=='positive']
Negative_sent = df[df['sentiment']=='negative']
Neutral_sent = df[df['sentiment']=='neutral']

# %% [markdown]
# ### Most common positive words

# %%
#MosT common positive words
top = Counter([item for sublist in Positive_sent['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_77b9b_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_77b9b_row1_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_77b9b_row2_col1 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_77b9b_row3_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_77b9b_row4_col1 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_77b9b_row5_col1, #T_77b9b_row6_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_77b9b_row7_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_77b9b_row8_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_77b9b_row9_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_77b9b_row10_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_77b9b_row11_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_77b9b_row12_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_77b9b_row13_col1, #T_77b9b_row14_col1, #T_77b9b_row15_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_77b9b_row16_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_77b9b_row17_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_77b9b_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_77b9b_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_77b9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77b9b_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_77b9b_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77b9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77b9b_row0_col0" class="data row0 col0" >app</td>
#       <td id="T_77b9b_row0_col1" class="data row0 col1" >8559</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77b9b_row1_col0" class="data row1 col0" >good</td>
#       <td id="T_77b9b_row1_col1" class="data row1 col1" >4564</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77b9b_row2_col0" class="data row2 col0" >easy</td>
#       <td id="T_77b9b_row2_col1" class="data row2 col1" >3481</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77b9b_row3_col0" class="data row3 col0" >use</td>
#       <td id="T_77b9b_row3_col1" class="data row3 col1" >2606</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77b9b_row4_col0" class="data row4 col0" >great</td>
#       <td id="T_77b9b_row4_col1" class="data row4 col1" >2328</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77b9b_row5_col0" class="data row5 col0" >excellent</td>
#       <td id="T_77b9b_row5_col1" class="data row5 col1" >2118</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77b9b_row6_col0" class="data row6 col0" >nedbank</td>
#       <td id="T_77b9b_row6_col1" class="data row6 col1" >2107</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77b9b_row7_col0" class="data row7 col0" >best</td>
#       <td id="T_77b9b_row7_col1" class="data row7 col1" >1767</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77b9b_row8_col0" class="data row8 col0" >love</td>
#       <td id="T_77b9b_row8_col1" class="data row8 col1" >1638</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77b9b_row9_col0" class="data row9 col0" >bank</td>
#       <td id="T_77b9b_row9_col1" class="data row9 col1" >1401</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_77b9b_row10_col0" class="data row10 col0" >banking</td>
#       <td id="T_77b9b_row10_col1" class="data row10 col1" >1273</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_77b9b_row11_col0" class="data row11 col0" >money</td>
#       <td id="T_77b9b_row11_col1" class="data row11 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_77b9b_row12_col0" class="data row12 col0" >awesome</td>
#       <td id="T_77b9b_row12_col1" class="data row12 col1" >1038</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_77b9b_row13_col0" class="data row13 col0" >friendly</td>
#       <td id="T_77b9b_row13_col1" class="data row13 col1" >972</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_77b9b_row14_col0" class="data row14 col0" >make</td>
#       <td id="T_77b9b_row14_col1" class="data row14 col1" >968</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_77b9b_row15_col0" class="data row15 col0" >user</td>
#       <td id="T_77b9b_row15_col1" class="data row15 col1" >964</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_77b9b_row16_col0" class="data row16 col0" >like</td>
#       <td id="T_77b9b_row16_col1" class="data row16 col1" >889</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_77b9b_row17_col0" class="data row17 col0" >time</td>
#       <td id="T_77b9b_row17_col1" class="data row17 col1" >814</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_77b9b_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_77b9b_row18_col1" class="data row18 col1" >751</td>
#     </tr>
#     <tr>
#       <th id="T_77b9b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_77b9b_row19_col0" class="data row19 col0" >convenient</td>
#       <td id="T_77b9b_row19_col1" class="data row19 col1" >719</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()

# %% [markdown]
# ### Most common Negative words

# %%
#MosT common negative words
top = Counter([item for sublist in Negative_sent['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_e1bfb_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e1bfb_row1_col1 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_e1bfb_row2_col1 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_e1bfb_row3_col1 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_e1bfb_row4_col1 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_e1bfb_row5_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_e1bfb_row6_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_e1bfb_row7_col1 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_e1bfb_row8_col1 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_e1bfb_row9_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_e1bfb_row10_col1 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_e1bfb_row11_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_e1bfb_row12_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_e1bfb_row13_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_e1bfb_row14_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_e1bfb_row15_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_e1bfb_row16_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_e1bfb_row17_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_e1bfb_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e1bfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1bfb_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_e1bfb_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1bfb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e1bfb_row0_col0" class="data row0 col0" >time</td>
#       <td id="T_e1bfb_row0_col1" class="data row0 col1" >1105</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e1bfb_row1_col0" class="data row1 col0" >nedbank</td>
#       <td id="T_e1bfb_row1_col1" class="data row1 col1" >1086</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e1bfb_row2_col0" class="data row2 col0" >update</td>
#       <td id="T_e1bfb_row2_col1" class="data row2 col1" >990</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e1bfb_row3_col0" class="data row3 col0" >even</td>
#       <td id="T_e1bfb_row3_col1" class="data row3 col1" >870</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e1bfb_row4_col0" class="data row4 col0" >bank</td>
#       <td id="T_e1bfb_row4_col1" class="data row4 col1" >859</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e1bfb_row5_col0" class="data row5 col0" >log</td>
#       <td id="T_e1bfb_row5_col1" class="data row5 col1" >840</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e1bfb_row6_col0" class="data row6 col0" >money</td>
#       <td id="T_e1bfb_row6_col1" class="data row6 col1" >810</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e1bfb_row7_col0" class="data row7 col0" >open</td>
#       <td id="T_e1bfb_row7_col1" class="data row7 col1" >776</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e1bfb_row8_col0" class="data row8 col0" >account</td>
#       <td id="T_e1bfb_row8_col1" class="data row8 col1" >775</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e1bfb_row9_col0" class="data row9 col0" >keep</td>
#       <td id="T_e1bfb_row9_col1" class="data row9 col1" >768</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_e1bfb_row10_col0" class="data row10 col0" >work</td>
#       <td id="T_e1bfb_row10_col1" class="data row10 col1" >746</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_e1bfb_row11_col0" class="data row11 col0" >get</td>
#       <td id="T_e1bfb_row11_col1" class="data row11 col1" >732</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_e1bfb_row12_col0" class="data row12 col0" >error</td>
#       <td id="T_e1bfb_row12_col1" class="data row12 col1" >671</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_e1bfb_row13_col0" class="data row13 col0" >use</td>
#       <td id="T_e1bfb_row13_col1" class="data row13 col1" >655</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_e1bfb_row14_col0" class="data row14 col0" >working</td>
#       <td id="T_e1bfb_row14_col1" class="data row14 col1" >642</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_e1bfb_row15_col0" class="data row15 col0" >still</td>
#       <td id="T_e1bfb_row15_col1" class="data row15 col1" >612</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_e1bfb_row16_col0" class="data row16 col0" >say</td>
#       <td id="T_e1bfb_row16_col1" class="data row16 col1" >606</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_e1bfb_row17_col0" class="data row17 col0" >problem</td>
#       <td id="T_e1bfb_row17_col1" class="data row17 col1" >577</td>
#     </tr>
#     <tr>
#       <th id="T_e1bfb_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_e1bfb_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_e1bfb_row18_col1" class="data row18 col1" >574</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_negative, x="count", y="Common_words", title='Most Commmon negative Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()

# %% [markdown]
# ### Most common Neutral words

# %%
#MosT common Neutral words
top = Counter([item for sublist in Neutral_sent['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_5f44a_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5f44a_row1_col1, #T_5f44a_row2_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_5f44a_row3_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_5f44a_row4_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_5f44a_row5_col1 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_5f44a_row6_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_5f44a_row7_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_5f44a_row8_col1, #T_5f44a_row9_col1 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_5f44a_row10_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_5f44a_row11_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_5f44a_row12_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_5f44a_row13_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_5f44a_row14_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_5f44a_row15_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_5f44a_row16_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_5f44a_row17_col1, #T_5f44a_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5f44a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f44a_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_5f44a_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f44a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5f44a_row0_col0" class="data row0 col0" >good</td>
#       <td id="T_5f44a_row0_col1" class="data row0 col1" >288</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5f44a_row1_col0" class="data row1 col0" >update</td>
#       <td id="T_5f44a_row1_col1" class="data row1 col1" >156</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5f44a_row2_col0" class="data row2 col0" >account</td>
#       <td id="T_5f44a_row2_col1" class="data row2 col1" >156</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5f44a_row3_col0" class="data row3 col0" >money</td>
#       <td id="T_5f44a_row3_col1" class="data row3 col1" >143</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_5f44a_row4_col0" class="data row4 col0" >use</td>
#       <td id="T_5f44a_row4_col1" class="data row4 col1" >134</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_5f44a_row5_col0" class="data row5 col0" >nedbank</td>
#       <td id="T_5f44a_row5_col1" class="data row5 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_5f44a_row6_col0" class="data row6 col0" >time</td>
#       <td id="T_5f44a_row6_col1" class="data row6 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_5f44a_row7_col0" class="data row7 col0" >please</td>
#       <td id="T_5f44a_row7_col1" class="data row7 col1" >120</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_5f44a_row8_col0" class="data row8 col0" >need</td>
#       <td id="T_5f44a_row8_col1" class="data row8 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_5f44a_row9_col0" class="data row9 col0" >bank</td>
#       <td id="T_5f44a_row9_col1" class="data row9 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_5f44a_row10_col0" class="data row10 col0" >work</td>
#       <td id="T_5f44a_row10_col1" class="data row10 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_5f44a_row11_col0" class="data row11 col0" >get</td>
#       <td id="T_5f44a_row11_col1" class="data row11 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_5f44a_row12_col0" class="data row12 col0" >problem</td>
#       <td id="T_5f44a_row12_col1" class="data row12 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_5f44a_row13_col0" class="data row13 col0" >open</td>
#       <td id="T_5f44a_row13_col1" class="data row13 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_5f44a_row14_col0" class="data row14 col0" >want</td>
#       <td id="T_5f44a_row14_col1" class="data row14 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_5f44a_row15_col0" class="data row15 col0" >option</td>
#       <td id="T_5f44a_row15_col1" class="data row15 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_5f44a_row16_col0" class="data row16 col0" >like</td>
#       <td id="T_5f44a_row16_col1" class="data row16 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_5f44a_row17_col0" class="data row17 col0" >new</td>
#       <td id="T_5f44a_row17_col1" class="data row17 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_5f44a_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_5f44a_row18_col0" class="data row18 col0" >log</td>
#       <td id="T_5f44a_row18_col1" class="data row18 col1" >85</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_neutral, x="count", y="Common_words", title='Most Commmon Neutral Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()

# %% [markdown]
# ## **Wordcloud**

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), color = 'white',
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'u', "im"}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color=color,
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size,
                    random_state = 42,
                    width=400,
                    height=200,
                    mask = mask)
    wordcloud.generate(str(text))

    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black',
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()
d = '/kaggle/input/masks-for-wordclouds/'

# %%
cyberpunk_palette = ["#FF00FF", "#00FF00", "#0000FF"]
template = "plotly_dark"

# %%
# Word Length Distribution
word_lengths = [len(word) for text in df['content'] for word in text.split()]
word_lengths_counts = {length: word_lengths.count(length) for length in set(word_lengths)}

# Sort the word lengths by count in descending order
sorted_word_lengths = sorted(word_lengths_counts.items(), key=lambda x: x[1], reverse=True)
# Create a custom colorscale with a fixed number of colors
colorscale = colors.sample_colorscale('Viridis', len(word_lengths_counts))

# %%
# Create the bar chart trace
bar_trace = go.Bar(
    x=[length for length, count in sorted_word_lengths],
    y=[count for length, count in sorted_word_lengths],
    marker=dict(
        color=[colorscale[i] for i in range(len(sorted_word_lengths))],
        line=dict(
            color=cyberpunk_palette[0],
            width=2
        )
    ),
    hovertemplate='Word Length: %{x}<br>Count: %{y}<extra></extra>'
)

# %%
# Create the neon light effect trace
light_effect_trace = go.Scatter(
    x=[length for length, count in sorted_word_lengths],
    y=[count * 1.05 for length, count in sorted_word_lengths],
    mode='lines',
    line=dict(
        color=cyberpunk_palette[1],
        width=5
    ),
    hoverinfo='skip'
)

# %%
# Create the layout
layout = go.Layout(
    title="Word Length Distribution",
    xaxis=dict(
        title="Word Length",
        tickfont=dict(color=cyberpunk_palette[2])
    ),
    yaxis=dict(
        title="Count",
        tickfont=dict(color=cyberpunk_palette[2])
    ),
    plot_bgcolor="black",
    paper_bgcolor="black",
    font_color=cyberpunk_palette[2],
    title_font_color=cyberpunk_palette[2],
    title_font_size=20,
    margin=dict(t=80, l=100, r=50, b=100)
)

# Create the figure and show it
fig = go.Figure(data=[bar_trace, light_effect_trace], layout=layout)
fig.show()

# %%
# Sentence Length Distribution
sentence_lengths = [len(text.split()) for text in df['content']]

# Create a custom colorscale with a fixed number of colors
colorscale = colors.sample_colorscale('Viridis', len(set(sentence_lengths)))

bar_trace = go.Bar(
    x=sorted(set(sentence_lengths)),
    y=[sentence_lengths.count(length) for length in sorted(set(sentence_lengths))],
    marker=dict(
        color=[colorscale[i] for i in range(len(set(sentence_lengths)))],
        line=dict(
            color=cyberpunk_palette[0],
            width=2
        )
    ),
    hovertemplate='Sentence Length: %{x}<br>Count: %{y}<extra></extra>'
)

# %%
light_effect_trace = go.Scatter(
    x=sorted(set(sentence_lengths)),
    y=[sentence_lengths.count(length) * 1.05 for length in sorted(set(sentence_lengths))],
    mode='lines',
    line=dict(
        color=cyberpunk_palette[1],
        width=5
    ),
    hoverinfo='skip'
)

# %%
layout = go.Layout(
    title="Sentence Length Distribution",
    xaxis=dict(
        title="Sentence Length",
        tickfont=dict(color=cyberpunk_palette[2])
    ),
    yaxis=dict(
        title="Count",
        tickfont=dict(color=cyberpunk_palette[2])
    ),
    plot_bgcolor="black",
    paper_bgcolor="black",
    font_color=cyberpunk_palette[2],
    title_font_color=cyberpunk_palette[2],
    title_font_size=20,
    margin=dict(t=80, l=100, r=50, b=100)
)
fig = go.Figure(data=[bar_trace, light_effect_trace], layout=layout)
fig.show()

# %% [markdown]
# ### Word cloud for positive Sentiment

# %%
# Word Cloud for Positive Sentiment
positive_text = ' '.join(df[df['sentiment'] == 'positive']['content'])
wordcloud = WordCloud(background_color='black', width = 800, height = 400, max_words=200, colormap='Greens').generate(positive_text)
fig = go.Figure(go.Image(z = np.dstack((wordcloud.to_array(), wordcloud.to_array(), wordcloud.to_array()))))
fig.update_layout(
    title = 'Word Cloud For Positive Sentiment',
    template = template,
    plot_bgcolor = 'black',
    paper_bgcolor = 'black',
    font_color = cyberpunk_palette[2],
    title_font_color = cyberpunk_palette[2],
    title_font_size = 20,
    margin = dict(t = 80, l = 50, r = 50, b = 50)
)
fig.show()

# %% [markdown]
# ### word cloud for Negative Sentiment

# %%
# Word Cloud for Negative Sentiment
negative_text = ' '.join(df[df['sentiment'] == 'negative']['content'])
wordcloud = WordCloud(background_color='black', width=800, height=400, max_words=200, colormap='Reds').generate(negative_text)
fig = go.Figure(go.Image(z=np.dstack((wordcloud.to_array(), wordcloud.to_array(), wordcloud.to_array()))))
fig.update_layout(
    title="Word Cloud for Negative Sentiment",
    template=template,
    plot_bgcolor="black",
    paper_bgcolor="black",
    font_color=cyberpunk_palette[2],
    title_font_color=cyberpunk_palette[2],
    title_font_size=20,
    margin=dict(t=80, l=50, r=50, b=50)
)
fig.show()
# Out:
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 58186)
# Traceback (most recent call last):
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\socketserver.py", line 761, in __init__
#     self.handle()
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\http\server.py", line 436, in handle
#     self.handle_one_request()
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\http\server.py", line 424, in handle_one_request
#     method()
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_base_renderers.py", line 698, in do_GET
#     self.wfile.write(html[i : i + bufferSize])
#   File "c:\Users\202207760\AppData\Local\Programs\Python\Python312\Lib\socketserver.py", line 840, in write
#     self._sock.sendall(b)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ----------------------------------------

# %% [markdown]
# ### word cloud for Neutral Sentiment

# %%
# Word Cloud for Neutral Sentiment
neutral_text = ' '.join(df[df['sentiment'] == 'neutral']['content'])
wordcloud = WordCloud(background_color='black', width=800, height=400, max_words=200, colormap='Blues').generate(neutral_text)
fig = go.Figure(go.Image(z=np.dstack((wordcloud.to_array(), wordcloud.to_array(), wordcloud.to_array()))))
fig.update_layout(
    title="Word Cloud for Neutral Sentiment",
    template=template,
    plot_bgcolor="black",
    paper_bgcolor="black",
    font_color=cyberpunk_palette[2],
    title_font_color=cyberpunk_palette[2],
    title_font_size=20,
    margin=dict(t=80, l=50, r=50, b=50)
)
fig.show()

# %% [markdown]
# # ***MODELS BUILDING***

# %% [markdown]
# ## **BERT EMBEDDING**

# %%
# %pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: Pillow in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\202207760\appdata\roaming\python\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\202207760\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018B4D10E840>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sentence-transformers/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018B4D0FE210>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sentence-transformers/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018B4D0EE150>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sentence-transformers/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018B4D0EDDC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sentence-transformers/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018B4D0EDF10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sentence-transformers/

# %%
from sentence_transformers import SentenceTransformer

# %%
# =========================
# 1️⃣ Sentence Transformer Embeddings
# =========================
model = SentenceTransformer('all-MiniLM-L6-v2')
df['embedding'] = list(
    model.encode(df['clean_content'].tolist(), batch_size=32, show_progress_bar=True)
)
df['day'] = df['at'].dt.to_period('D').astype(str)
# Out:
# Batches:   0%|          | 0/1094 [00:00<?, ?it/s]

# %% [markdown]
# # Data leakage Handling and preprocessing

# %%
# =========================
# 2️⃣ Daily Aggregations
# =========================
daily_embeddings = df.groupby('day')['embedding'].apply(lambda emb: np.mean(np.stack(emb), axis=0)).reset_index()
daily_scores = df.groupby('day')['score'].mean().reset_index()
failures_per_day = df[df['score'] < 3].groupby('day').size().reset_index(name='failures_count')
total_per_day = df.groupby('day').size().reset_index(name='total_count')

daily_data = (
    daily_embeddings
    .merge(daily_scores, on='day')
    .merge(failures_per_day, on='day', how='left')
    .merge(total_per_day, on='day', how='left')
)
daily_data['failures_count'] = daily_data['failures_count'].fillna(0).astype(int)
daily_data['failure'] = (daily_data['score'] < 3).astype(int)

# %%
# =========================
# 3️⃣ Feature Engineering (Failures-based features)
# =========================
daily_data['failures_lag1'] = daily_data['failures_count'].shift(1).fillna(daily_data['failures_count'].mean())

daily_data['failures_ratio'] = daily_data['failures_lag1'] / (daily_data['failures_count'] + 1e-6)

daily_data['failures_roll_mean'] = (
    daily_data['failures_count'].shift(1)
    .rolling(window=3, min_periods=1)
    .mean()
    .fillna(daily_data['failures_count'].mean())
)

daily_data['failures_roll_std'] = (
    daily_data['failures_count'].shift(1)
    .rolling(window=3, min_periods=1)
    .std()
    .fillna(0)
)

daily_data['failures_delta'] = daily_data['failures_count'] - daily_data['failures_lag1']

# %%
daily_data
# Out:
#              day                                          embedding     score  \
# 0     2017-10-16  [-0.060089704, 0.007179315, -0.010648653, -0.0...  4.805970
# 1     2017-10-17  [-0.04769982, 0.0048278766, -0.016101496, -0.0...  4.675676
# 2     2017-10-18  [-0.07258853, 0.01511056, 0.0019812624, -0.044...  4.916667
# 3     2017-10-19  [-0.043888677, -0.004601855, -0.022257844, -0....  4.666667
# 4     2017-10-20  [-0.04782316, 0.016522162, -0.004149745, -0.03...  4.937500
# ...          ...                                                ...       ...
# 2628  2024-12-27  [0.0305536, -0.066259705, 0.061242867, -0.0815...  2.000000
# 2629  2024-12-28  [-0.010756671, 0.0056538377, -0.028213484, -0....  3.500000
# 2630  2024-12-29  [-0.071590096, 0.0076983226, -0.010560944, -0....  3.750000
# 2631  2024-12-30  [-0.062465534, -0.018956639, -0.012050379, 0.0...  5.000000
# 2632  2024-12-31  [-0.03739602, 0.01630548, -0.03013767, 0.00127...  4.200000
#
#       failures_count  total_count  failure  failures_lag1  failures_ratio  \
# 0                  1           67        0       3.137486    3.137483e+00
# 1                  2           37        0       1.000000    4.999998e-01
# 2                  0           12        0       2.000000    2.000000e+06
# 3                  0           12        0       0.000000    0.000000e+00
# 4                  0           16        0       0.000000    0.000000e+00
# ...              ...          ...      ...            ...             ...
# 2628               1            1        1       2.000000    1.999998e+00
# 2629               1            4        0       1.000000    9.999990e-01
# 2630               1            4        0       1.000000    9.999990e-01
# 2631               0            4        0       1.000000    1.000000e+06
# 2632               2           10        0       0.000000    0.000000e+00
#
#       failures_roll_mean  failures_roll_std  failures_delta
# 0               3.137486           0.000000       -2.137486
# 1               1.000000           0.000000        1.000000
# 2               1.500000           0.707107       -2.000000
# 3               1.000000           1.000000        0.000000
# 4               0.666667           1.154701        0.000000
# ...                  ...                ...             ...
# 2628            1.333333           1.154701       -1.000000
# 2629            1.000000           1.000000        0.000000
# 2630            1.333333           0.577350        0.000000
# 2631            1.000000           0.000000       -1.000000
# 2632            0.666667           0.577350        2.000000
#
# [2633 rows x 11 columns]

# %% [markdown]
# ## Train/Test split by Day (before fitting)

# %%
# =========================
# 4️⃣ Train/Test Split
# =========================
daily_data['day'] = pd.to_datetime(daily_data['day'])
split_idx = int(len(daily_data) * 0.8)
train_days = daily_data['day'].iloc[:split_idx]
test_days = daily_data['day'].iloc[split_idx:]

df['day'] = pd.to_datetime(df['day'])
df_train = df[df['day'].isin(train_days)]
df_test = df[df['day'].isin(test_days)]

# %% [markdown]
# ## Fit LDA Vectors on Training Only

# %%
# =========================
# 5️⃣ LDA Topic Modeling
# =========================
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
X_counts_train = vectorizer.fit_transform(df_train['clean_content'])
X_counts_test = vectorizer.transform(df_test['clean_content'])

# Choose best n topics using training only
topic_range = range(2, 21)
perplexities = []
for n in topic_range:
    lda = LatentDirichletAllocation(n_components=n, random_state=42)
    lda.fit(X_counts_train)
    perplexities.append(lda.perplexity(X_counts_train))

best_n = topic_range[np.argmin(perplexities)]
lda_final = LatentDirichletAllocation(n_components=best_n, random_state=42)
lda_train = lda_final.fit_transform(X_counts_train)
lda_test = lda_final.transform(X_counts_test)

df_train['lda_vector'] = list(lda_train)
df_test['lda_vector'] = list(lda_test)

def aggregate_daily(df_subset):
    daily_emb = df_subset.groupby('day')['embedding'].apply(lambda e: np.mean(np.stack(e), axis=0)).reset_index()
    daily_lda = df_subset.groupby('day')['lda_vector'].apply(lambda v: np.mean(np.stack(v), axis=0)).reset_index()
    return daily_emb.merge(daily_lda, on='day')

daily_train = aggregate_daily(df_train).merge(daily_data, on='day')
daily_test = aggregate_daily(df_test).merge(daily_data, on='day')
# Out:
# C:\Users\202207760\AppData\Local\Temp\ipykernel_5248\3162645801.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\202207760\AppData\Local\Temp\ipykernel_5248\3162645801.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# =========================
# 6️⃣ PCA Dimensionality Reduction
# =========================
bert_array_train = np.vstack(daily_train['embedding_x'].values)
lda_array_train = np.vstack(daily_train['lda_vector'].values)

pca_bert = PCA(n_components=0.95, random_state=42)
bert_pca_train = pca_bert.fit_transform(bert_array_train)

pca_lda = PCA(n_components=0.95, random_state=42)
lda_pca_train = pca_lda.fit_transform(lda_array_train)

bert_array_test = np.vstack(daily_test['embedding_x'].values)
lda_array_test = np.vstack(daily_test['lda_vector'].values)

bert_pca_test = pca_bert.transform(bert_array_test)
lda_pca_test = pca_lda.transform(lda_array_test)

daily_train['embedding_pca'] = list(np.hstack([bert_pca_train, lda_pca_train]))
daily_test['embedding_pca'] = list(np.hstack([bert_pca_test, lda_pca_test]))

# %%
from sklearn.preprocessing import StandardScaler

# =========================
# 4️⃣ Structured Features (Failures-based)
# =========================
struct_features = [
    'failures_count',          # raw target signal included as feature
    'total_count',
    'failures_lag1', 
    'failures_ratio',
    'failures_roll_mean',
    'failures_roll_std',
    'failures_delta'
]

# Target variable (what we want to predict)
target_col = 'score'

# Separate features and target
X_train_struct = daily_train[struct_features].copy()
y_train = daily_train[target_col].copy()

X_test_struct = daily_test[struct_features].copy()
y_test = daily_test[target_col].copy()

# =========================
# Standardize Features
# =========================
scaler_struct = StandardScaler()

# Fit scaler only on train features (to prevent leakage)
X_struct_train = scaler_struct.fit_transform(X_train_struct)
X_struct_test = scaler_struct.transform(X_test_struct)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# =========================
# 7️⃣ Target:
# =========================
target_col = 'score'

scaler_y = MinMaxScaler()

# Scale target variable (for GRU stability)
y_train_scaled = scaler_y.fit_transform(daily_train[[target_col]]).flatten()
y_test_scaled = scaler_y.transform(daily_test[[target_col]]).flatten()

# =========================
# 8️⃣ Combine embeddings + structured features
# =========================
X_train = np.hstack([
    np.vstack(daily_train['embedding_pca']),   # embeddings
    X_struct_train                             # engineered features
])

X_test = np.hstack([
    np.vstack(daily_test['embedding_pca']), 
    X_struct_test
])

print("Train:", X_train.shape, y_train_scaled.shape)
print("Test:", X_test.shape, y_test_scaled.shape)
# Out:
# Train: (2106, 197) (2106,)
# Test: (527, 197) (527,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# =========================
# Create Sequences for RNN
# =========================
window_size = 3

def create_sequences(X, y, window_size):
    """
    Convert feature and target arrays into rolling windows for RNN input.
    X: shape (num_samples, feature_dim)
    y: shape (num_samples,)
    Returns:
        X_seq: shape (num_sequences, window_size, feature_dim)
        y_seq: shape (num_sequences,)
    """
    X_seq, y_seq = [], []
    
    # Start from window_size to predict the next step after the window
    for i in range(window_size, len(X)):
        # Take the previous `window_size` steps as input
        X_seq.append(X[i-window_size:i])
        
        # Take the current step as the target (next step)
        y_seq.append(y[i])
        
    return np.array(X_seq), np.array(y_seq)

# Ensure inputs are numpy arrays
X_train = np.array(X_train)
y_train_scaled = np.array(y_train_scaled)
X_test = np.array(X_test)
y_test_scaled = np.array(y_test_scaled)

# Generate sequences
X_train_seq, y_train_seq = create_sequences(X_train, y_train_scaled, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_scaled, window_size)

print("Train sequences:", X_train_seq.shape, y_train_seq.shape)
print("Test sequences:", X_test_seq.shape, y_test_seq.shape)
# Out:
# Train sequences: (2103, 3, 197) (2103,)
# Test sequences: (524, 3, 197) (524,)

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# Build LSTM Model
model = Sequential([
    LSTM(64, activation='tanh', return_sequences=True,
         input_shape=(window_size, X_train_seq.shape[2]), kernel_regularizer=l2(0.0001)),
    LSTM(32, activation='tanh', kernel_regularizer=l2(0.0001)),
    Dropout(0.3),
    Dense(32, activation='relu', kernel_regularizer=l2(0.0001)),
    Dropout(0.3),
    Dense(1, activation='linear', kernel_regularizer=l2(0.0001))
])

# Compile the model
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_mae', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# C:\Users\202207760\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.4199 - mae: 0.5810 - val_loss: 0.0571 - val_mae: 0.1620
# Epoch 2/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0637 - mae: 0.1771 - val_loss: 0.0499 - val_mae: 0.1516
# Epoch 3/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0566 - mae: 0.1693 - val_loss: 0.0479 - val_mae: 0.1504
# Epoch 4/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0501 - mae: 0.1610 - val_loss: 0.0455 - val_mae: 0.1498
# Epoch 5/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0467 - mae: 0.1567 - val_loss: 0.0450 - val_mae: 0.1500
# Epoch 6/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0463 - mae: 0.1582 - val_loss: 0.0443 - val_mae: 0.1511
# Epoch 7/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0429 - mae: 0.1522 - val_loss: 0.0453 - val_mae: 0.1512
# Epoch 8/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0420 - mae: 0.1526 - val_loss: 0.0442 - val_mae: 0.1524
# Epoch 9/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0388 - mae: 0.1450 - val_loss: 0.0438 - val_mae: 0.1505

# %%
# =========================
# Evaluate Model Performance on Test Set (failures_count)
# =========================
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy.ndimage import gaussian_filter1d
import numpy as np

# --- Direct evaluation from Keras ---
loss, mae = model.evaluate(X_test_seq, y_test_seq, verbose=0)
print(f"\nTest MSE (from model.evaluate): {loss:.4f}")
print(f"Test MAE (from model.evaluate): {mae:.4f}")

# --- Predict failures_count on test sequence data ---
y_pred_scaled = model.predict(X_test_seq, verbose=0).flatten()

# Inverse transform to original failure counts
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
y_test = scaler_y.inverse_transform(y_test_seq.reshape(-1, 1)).flatten()

# --- Compute regression metrics (raw, no smoothing) ---
mse = mean_squared_error(y_test, y_pred)
mae_raw = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nRaw Results (no smoothing) for failures_count")
print(f"MAE: {mae_raw:.4f}")
print(f"MSE: {mse:.4f}")
print(f"R²:  {r2:.4f}")

# --- Apply Gaussian smoothing ---
sigma_value = 1.5
y_pred_smoothed = gaussian_filter1d(y_pred, sigma=sigma_value)
y_test_smoothed = gaussian_filter1d(y_test, sigma=sigma_value)

# --- Metrics for smoothed results ---
mse_smooth = mean_squared_error(y_test_smoothed, y_pred_smoothed)
mae_smooth = mean_absolute_error(y_test_smoothed, y_pred_smoothed)
r2_smooth = r2_score(y_test_smoothed, y_pred_smoothed)

print(f"\nSmoothed Results (σ={sigma_value}) for failures_count")
print(f"MAE: {mae_smooth:.4f}")
print(f"MSE: {mse_smooth:.4f}")
print(f"R²:  {r2_smooth:.4f}")

# --- Sample predictions vs actual ---
print("\nSample Predictions (smoothed vs actual):")
for actual, predicted in zip(y_test_smoothed[:10], y_pred_smoothed[:10]):
    print(f"Actual: {actual:.2f} | Predicted: {predicted:.2f}")
# Out:
# Test MSE (from model.evaluate): 0.0455
# Test MAE (from model.evaluate): 0.1498
#
# Raw Results (no smoothing) for failures_count
# MAE: 0.5991
# MSE: 0.5971
# R²:  0.0025
#
# Smoothed Results (σ=1.5) for failures_count
# MAE: 0.2736
# MSE: 0.1242
# R²:  0.1584
#
# Sample Predictions (smoothed vs actual):
# Actual: 3.61 | Predicted: 3.81
# Actual: 3.89 | Predicted: 3.78
# Actual: 4.25 | Predicted: 3.76
# Actual: 4.45 | Predicted: 3.76
# Actual: 4.40 | Predicted: 3.82
# Actual: 4.18 | Predicted: 3.89
# Actual: 3.94 | Predicted: 3.92
# Actual: 3.75 | Predicted: 3.89
# Actual: 3.62 | Predicted: 3.84
# Actual: 3.52 | Predicted: 3.79

# %%
# =========================
# 9️⃣ Predict + inverse scale
# =========================
from scipy.ndimage import gaussian_filter1d

# Predict on test sequences
y_pred = model.predict(X_test_seq).flatten()

# Inverse scale predictions and actuals (back to score units)
y_pred_inv = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_inv = scaler_y.inverse_transform(y_test_seq.reshape(-1, 1)).flatten()

# Smooth for visualization (Gaussian filter)
sigma_value = 1.5
y_pred_smooth = gaussian_filter1d(y_pred_inv, sigma=sigma_value)
y_test_smooth = gaussian_filter1d(y_test_inv, sigma=sigma_value)

# Build forecast DataFrame
df_forecast = pd.DataFrame({
    'Day': daily_test['day'].iloc[window_size - 1 : window_size - 1 + len(y_test_seq)].values,
    'Actual_Score': y_test_inv,
    'Predicted_Score': y_pred_inv,
    'Actual_Score_Smoothed': y_test_smooth,
    'Predicted_Score_Smoothed': y_pred_smooth
})

print(df_forecast.head())
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#          Day  Actual_Score  Predicted_Score  Actual_Score_Smoothed  \
# 0 2023-12-20      3.857143         3.688086               3.728753
# 1 2023-12-21      3.350000         3.631927               3.753060
# 2 2023-12-22      4.090909         3.888358               3.775562
# 3 2023-12-23      3.892857         3.938916               3.722029
# 4 2023-12-24      4.000000         3.896723               3.584882
#
#    Predicted_Score_Smoothed
# 0                  3.710846
# 1                  3.743879
# 2                  3.774234
# 3                  3.743265
# 4                  3.649680

# %%
import matplotlib.pyplot as plt

# ===  Training history ===
plt.figure(figsize=(12, 5))

# Plot MAE
plt.subplot(1, 2, 1)
plt.plot(history.history['mae'], label='Train MAE', color='blue')
plt.plot(history.history['val_mae'], label='Val MAE', color='orange')
plt.title('Model Mean Absolute Error (Training)')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot Loss (MSE)
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange')
plt.title('Model Loss (MSE) (Training)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# === Predictions vs Actuals (Score over time) ===
plt.figure(figsize=(14, 6))

# Limit view for readability (e.g., first 200 points)
N = 200
days_plot = df_forecast['Day'][:N]

# Plot raw predictions vs actual
plt.subplot(1, 2, 1)
plt.plot(days_plot, df_forecast['Actual_Score'][:N], label='Actual', alpha=0.8)
plt.plot(days_plot, df_forecast['Predicted_Score'][:N], label='Predicted (raw)', alpha=0.8)
plt.title('Predicted vs Actual Score (Raw)')
plt.xlabel('Day')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)

# Plot smoothed predictions vs actual
plt.subplot(1, 2, 2)
plt.plot(days_plot, df_forecast['Actual_Score_Smoothed'][:N], label='Actual (Smoothed)', alpha=0.8)
plt.plot(days_plot, df_forecast['Predicted_Score_Smoothed'][:N], label='Predicted (Smoothed)', alpha=0.8)
plt.title('Predicted vs Actual Score (Smoothed)')
plt.xlabel('Day')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from scipy.ndimage import gaussian_filter1d

# --- Parameters ---
FUTURE_STEPS = 3
window_size = X_test_seq.shape[1]  # must match training window
last_known_day = daily_data['day'].max()  # last day in your dataset

# --- Prepare last input sequence from test data ---
X_last_window = np.expand_dims(X_test_seq[-1], axis=0)  # shape: (1, window_size, feature_dim)

future_scores = []
future_days = []

for step in range(1, FUTURE_STEPS + 1):
    # Predict scaled value
    pred_scaled = model.predict(X_last_window, verbose=0).flatten()[0]
    # Inverse scale to original range
    pred_score = scaler_y.inverse_transform([[pred_scaled]])[0, 0]
    future_scores.append(pred_score)

    # Next day
    next_day = last_known_day + pd.Timedelta(days=step)
    future_days.append(next_day)

    # --- Update rolling window with predicted value ---
    new_window = X_last_window[0, 1:, :].copy()  # drop first day from window
    new_step = X_last_window[0, -1, :].copy()   # copy last day features

    # Replace target feature with predicted scaled value
    # Assuming the first column of X is the target-related feature (score)
    new_step[0] = pred_scaled

    # Append predicted step to window
    new_window = np.vstack([new_window, new_step])
    X_last_window = np.expand_dims(new_window, axis=0)

# --- Build forecast DataFrame ---
df_future = pd.DataFrame({
    'Day': future_days,
    'Predicted_Score_Smoothed': gaussian_filter1d(future_scores, sigma=1)
})

# --- Add placeholders for hover features (failure count + engineered stats) ---
hover_features = [
    'failures_count',    # keep failure count as feature
    'total_count',
    'failures_lag1',     # if you engineered lagged failure features
    'failures_ratio',
    'failures_roll_mean',
    'failures_roll_std',
    'failures_delta'
]
df_future['Review_Summary'] = 'No reviews yet'
for f in hover_features:
    df_future[f] = np.nan

print("Future Forecast for Next 3 Days:")
print(df_future[['Day', 'Predicted_Score_Smoothed']])
# Out:
# Future Forecast for Next 3 Days:
#          Day  Predicted_Score_Smoothed
# 0 2025-01-01                  4.042993
# 1 2025-01-02                  4.257812
# 2 2025-01-03                  4.434311

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# =========================
# Hover Features (failure count + engineered stats)
# =========================
hover_features = [
    'failures_count',      # keep failure count as feature
    'total_count',
    'failures_lag1',       # lagged failure count
    'failures_ratio',
    'failures_roll_mean',
    'failures_roll_std',
    'failures_delta'
]

# =========================
# Merge Forecast + Features
# =========================
df_hover = (
    df_forecast.merge(
        daily_data[['day'] + hover_features],
        left_on='Day', right_on='day', how='left'
    )
)

df_hover = df_hover[['Day', 'Actual_Score_Smoothed', 'Predicted_Score_Smoothed'] + hover_features]

# =========================
# Future Forecast Placeholders
# =========================
for f in hover_features:
    df_future[f] = np.nan

# =========================
# Risk Threshold (score < 3 means HIGH risk)
# =========================
threshold = 3.0
df_hover['High_Risk'] = df_hover['Predicted_Score_Smoothed'] < threshold
# ⚠️ Fix: future should use its forecast column, not Predicted
df_future['High_Risk'] = df_future['Predicted_Score_Smoothed'] < threshold

# =========================
# Customdata for Hover
# =========================
def get_customdata(df_set):
    return np.stack([
        df_set.get('failures_count', pd.Series(0)).fillna(0),
        df_set.get('failures_lag1', pd.Series(0)).fillna(0),
        df_set.get('failures_ratio', pd.Series(0)).fillna(0),
        df_set.get('failures_roll_mean', pd.Series(0)).fillna(0),
        df_set.get('failures_roll_std', pd.Series(0)).fillna(0),
        df_set.get('failures_delta', pd.Series(0)).fillna(0),
        df_set.get('total_count', pd.Series(0)).fillna(0)
    ], axis=-1)

customdata_hover = get_customdata(pd.concat([df_hover, df_future], ignore_index=True))

# =========================
# Plotly Interactive Graph
# =========================
fig = go.Figure()

# --- Actual Score ---
fig.add_trace(go.Scatter(
    x=df_hover['Day'],
    y=df_hover['Actual_Score_Smoothed'],
    mode='lines+markers',
    name='Actual Score',
    line=dict(color='blue', width=2),
    customdata=customdata_hover[:len(df_hover)],
    hovertemplate=(
        'Date: %{x}<br>Actual Score: %{y:.2f}<br>'
        'Failures Count: %{customdata[0]:.0f}<br>'
        'Lag1: %{customdata[1]:.2f}<br>'
        'Ratio: %{customdata[2]:.2f}<br>'
        'Roll Mean: %{customdata[3]:.2f}<br>'
        'Roll Std: %{customdata[4]:.2f}<br>'
        'Delta: %{customdata[5]:.2f}<br>'
        'Total Count: %{customdata[6]:.0f}<extra></extra>'
    )
))

# --- Predicted Score (Historical) ---
fig.add_trace(go.Scatter(
    x=df_hover['Day'],
    y=df_hover['Predicted_Score_Smoothed'],
    mode='lines+markers',
    name='Predicted Score',
    line=dict(color='red', width=2),
    customdata=customdata_hover[:len(df_hover)],
    hovertemplate=(
        'Date: %{x}<br>Predicted Score: %{y:.2f}<br>'
        'Failures Count: %{customdata[0]:.0f}<br>'
        'Lag1: %{customdata[1]:.2f}<br>'
        'Ratio: %{customdata[2]:.2f}<br>'
        'Roll Mean: %{customdata[3]:.2f}<br>'
        'Roll Std: %{customdata[4]:.2f}<br>'
        'Delta: %{customdata[5]:.2f}<br>'
        'Total Count: %{customdata[6]:.0f}<extra></extra>'
    )
))

# --- Predicted Score (Future Forecast) ---
fig.add_trace(go.Scatter(
    x=df_future['Day'],
    y=df_future['Predicted_Score_Smoothed'],  # ⚠️ this must exist in df_future
    mode='lines+markers',
    name='Future Forecast',
    line=dict(color='orange', width=2, dash='dash'),
    customdata=customdata_hover[len(df_hover):],
    hovertemplate=(
        'Date: %{x}<br>Forecast Score: %{y:.2f}<br>'
        'Failures Count: %{customdata[0]:.0f}<br>'
        'Lag1: %{customdata[1]:.2f}<br>'
        'Ratio: %{customdata[2]:.2f}<br>'
        'Roll Mean: %{customdata[3]:.2f}<br>'
        'Roll Std: %{customdata[4]:.2f}<br>'
        'Delta: %{customdata[5]:.2f}<br>'
        'Total Count: %{customdata[6]:.0f}<extra></extra>'
    )
))

# =========================
# Risk Zones (continuous shading)
# =========================
def add_risk_zones(fig, df_set):
    days = pd.to_datetime(df_set['Day'])
    high_risk = df_set['High_Risk'].values

    start = None
    for i in range(len(high_risk)):
        if high_risk[i] and start is None:
            start = days.iloc[i]
        elif not high_risk[i] and start is not None:
            end = days.iloc[i]
            fig.add_vrect(
                x0=start, x1=end,
                fillcolor="red", opacity=0.2,
                layer="below", line_width=0
            )
            start = None
    if start is not None:
        fig.add_vrect(
            x0=start, x1=days.iloc[-1] + pd.Timedelta(days=1),
            fillcolor="red", opacity=0.2,
            layer="below", line_width=0
        )

# Apply risk shading
add_risk_zones(fig, df_hover)
add_risk_zones(fig, df_future)

# --- Threshold Line ---
fig.add_hline(
    y=threshold,
    line=dict(color="orange", width=2, dash="dash"),
    annotation_text=f"Risk Threshold ({threshold})",
    annotation_position="bottom right"
)

# --- Layout ---
fig.update_layout(
    title='Time Series: Actual, Predicted, and Future Forecast with Risk Zones',
    xaxis_title='Date',
    yaxis_title='Score',
    hovermode='x unified',
    template='plotly_white'
)

fig.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# -------------------------
# Top words for business SHAP
# -------------------------
top_words = df['clean_content'].str.split() \
           .explode() \
           .value_counts().head(100).index.tolist()

vectorizer = CountVectorizer(vocabulary=top_words)

def daily_word_counts(df_subset):
    """
    Aggregate word counts per day
    """
    counts = vectorizer.transform(df_subset['clean_content'])
    daily_counts = df_subset.groupby('day').apply(
        lambda x: np.sum(vectorizer.transform(x['clean_content']), axis=0)
    )
    # Convert sparse matrix to dense array
    daily_counts = np.vstack(daily_counts.values)
    return daily_counts

# Daily word counts
X_words_train_daily = daily_word_counts(df_train)
X_words_test_daily = daily_word_counts(df_test)

# Combine with structured features (now row counts match)
X_train_interpretable = np.hstack([X_train_struct.values, X_words_train_daily])
X_test_interpretable = np.hstack([X_test_struct.values, X_words_test_daily])

feature_names = list(X_train_struct.columns) + top_words
# Out:
# C:\Users\PLubi\AppData\Local\Temp\ipykernel_53148\3099273915.py:18: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PLubi\AppData\Local\Temp\ipykernel_53148\3099273915.py:18: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\plubi\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\plubi\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.16.2)
# Downloading xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/56.8 MB 435.7 kB/s eta 0:02:11
#    ---------------------------------------- 0.1/56.8 MB 1.0 MB/s eta 0:00:56
#    ---------------------------------------- 0.5/56.8 MB 2.8 MB/s eta 0:00:21
#     --------------------------------------- 0.9/56.8 MB 4.2 MB/s eta 0:00:14
#     --------------------------------------- 1.3/56.8 MB 5.2 MB/s eta 0:00:11
#    - -------------------------------------- 1.7/56.8 MB 5.8 MB/s eta 0:00:10
#    - -------------------------------------- 2.2/56.8 MB 6.2 MB/s eta 0:00:09
#    - -------------------------------------- 2.6/56.8 MB 6.7 MB/s eta 0:00:09
#    -- ------------------------------------- 2.9/56.8 MB 6.7 MB/s eta 0:00:09
#    -- ------------------------------------- 3.3/56.8 MB 7.1 MB/s eta 0:00:08
#    -- ------------------------------------- 3.6/56.8 MB 7.0 MB/s eta 0:00:08
#    -- ------------------------------------- 4.0/56.8 MB 7.1 MB/s eta 0:00:08
#    --- ------------------------------------ 4.4/56.8 MB 7.2 MB/s eta 0:00:08
#    --- ------------------------------------ 4.7/56.8 MB 7.2 MB/s eta 0:00:08
#    --- ------------------------------------ 5.2/56.8 MB 7.4 MB/s eta 0:00:07
#    --- ------------------------------------ 5.5/56.8 MB 7.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 5.9/56.8 MB 7.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 6.2/56.8 MB 7.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 6.7/56.8 MB 7.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 7.1/56.8 MB 7.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 7.5/56.8 MB 7.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 7.9/56.8 MB 7.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 8.3/56.8 MB 7.7 MB/s eta 0:00:07
#    ------ --------------------------------- 8.7/56.8 MB 7.7 MB/s eta 0:00:07
#    ------ --------------------------------- 8.9/56.8 MB 7.6 MB/s eta 0:00:07
#    ------ --------------------------------- 9.4/56.8 MB 7.7 MB/s eta 0:00:07
#    ------ --------------------------------- 9.7/56.8 MB 7.6 MB/s eta 0:00:07
#    ------ --------------------------------- 9.9/56.8 MB 7.5 MB/s eta 0:00:07
#    ------- -------------------------------- 10.3/56.8 MB 8.1 MB/s eta 0:00:06
#    ------- -------------------------------- 10.6/56.8 MB 8.1 MB/s eta 0:00:06
#    ------- -------------------------------- 11.0/56.8 MB 8.1 MB/s eta 0:00:06
#    ------- -------------------------------- 11.4/56.8 MB 8.0 MB/s eta 0:00:06
#    -------- ------------------------------- 11.7/56.8 MB 8.1 MB/s eta 0:00:06
#    -------- ------------------------------- 12.1/56.8 MB 8.0 MB/s eta 0:00:06
#    -------- ------------------------------- 12.7/56.8 MB 8.0 MB/s eta 0:00:06
#    --------- ------------------------------ 13.1/56.8 MB 8.2 MB/s eta 0:00:06
#    --------- ------------------------------ 13.5/56.8 MB 8.1 MB/s eta 0:00:06
#    --------- ------------------------------ 13.8/56.8 MB 8.1 MB/s eta 0:00:06
#    --------- ------------------------------ 14.1/56.8 MB 8.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 14.4/56.8 MB 7.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 14.7/56.8 MB 7.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 15.1/56.8 MB 8.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 15.3/56.8 MB 7.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 15.6/56.8 MB 7.8 MB/s eta 0:00:06
#    ----------- ---------------------------- 16.0/56.8 MB 7.9 MB/s eta 0:00:06
#    ----------- ---------------------------- 16.5/56.8 MB 7.9 MB/s eta 0:00:06
#    ----------- ---------------------------- 16.8/56.8 MB 7.9 MB/s eta 0:00:06
#    ------------ --------------------------- 17.2/56.8 MB 7.9 MB/s eta 0:00:06
#    ------------ --------------------------- 17.6/56.8 MB 7.8 MB/s eta 0:00:06
#    ------------ --------------------------- 17.9/56.8 MB 7.8 MB/s eta 0:00:05
#    ------------ --------------------------- 18.3/56.8 MB 7.7 MB/s eta 0:00:06
#    ------------- -------------------------- 18.6/56.8 MB 7.6 MB/s eta 0:00:06
#    ------------- -------------------------- 18.9/56.8 MB 7.6 MB/s eta 0:00:05
#    ------------- -------------------------- 19.2/56.8 MB 7.6 MB/s eta 0:00:05
#    ------------- -------------------------- 19.4/56.8 MB 7.5 MB/s eta 0:00:05
#    ------------- -------------------------- 19.7/56.8 MB 7.4 MB/s eta 0:00:05
#    -------------- ------------------------- 20.1/56.8 MB 7.5 MB/s eta 0:00:05
#    -------------- ------------------------- 20.3/56.8 MB 7.4 MB/s eta 0:00:05
#    -------------- ------------------------- 20.7/56.8 MB 7.5 MB/s eta 0:00:05
#    -------------- ------------------------- 21.0/56.8 MB 7.4 MB/s eta 0:00:05
#    -------------- ------------------------- 21.2/56.8 MB 7.4 MB/s eta 0:00:05
#    --------------- ------------------------ 21.5/56.8 MB 7.4 MB/s eta 0:00:05
#    --------------- ------------------------ 21.8/56.8 MB 7.2 MB/s eta 0:00:05
#    --------------- ------------------------ 22.0/56.8 MB 7.1 MB/s eta 0:00:05
#    --------------- ------------------------ 22.3/56.8 MB 7.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 22.8/56.8 MB 7.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 23.0/56.8 MB 7.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 23.3/56.8 MB 7.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 23.7/56.8 MB 6.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 23.9/56.8 MB 6.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 24.4/56.8 MB 6.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 24.8/56.8 MB 7.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 25.1/56.8 MB 7.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 25.5/56.8 MB 7.1 MB/s eta 0:00:05
#    ------------------ --------------------- 25.9/56.8 MB 7.2 MB/s eta 0:00:05
#    ------------------ --------------------- 26.2/56.8 MB 7.1 MB/s eta 0:00:05
#    ------------------ --------------------- 26.2/56.8 MB 7.1 MB/s eta 0:00:05
#    ------------------ --------------------- 26.2/56.8 MB 7.1 MB/s eta 0:00:05
#    ------------------ --------------------- 26.2/56.8 MB 7.1 MB/s eta 0:00:05
#    ------------------ --------------------- 26.4/56.8 MB 6.4 MB/s eta 0:00:05
#    ------------------ --------------------- 26.6/56.8 MB 6.3 MB/s eta 0:00:05
#    ------------------ --------------------- 26.9/56.8 MB 6.2 MB/s eta 0:00:05
#    ------------------- -------------------- 27.3/56.8 MB 6.2 MB/s eta 0:00:05
#    ------------------- -------------------- 27.6/56.8 MB 6.2 MB/s eta 0:00:05
#    ------------------- -------------------- 27.9/56.8 MB 6.2 MB/s eta 0:00:05
#    ------------------- -------------------- 28.1/56.8 MB 6.1 MB/s eta 0:00:05
#    -------------------- ------------------- 28.4/56.8 MB 6.1 MB/s eta 0:00:05
#    -------------------- ------------------- 28.8/56.8 MB 6.1 MB/s eta 0:00:05
#    -------------------- ------------------- 29.2/56.8 MB 6.1 MB/s eta 0:00:05
#    -------------------- ------------------- 29.5/56.8 MB 6.1 MB/s eta 0:00:05
#    -------------------- ------------------- 29.8/56.8 MB 6.2 MB/s eta 0:00:05
#    --------------------- ------------------ 30.1/56.8 MB 6.2 MB/s eta 0:00:05
#    --------------------- ------------------ 30.4/56.8 MB 6.2 MB/s eta 0:00:05
#    --------------------- ------------------ 30.8/56.8 MB 6.2 MB/s eta 0:00:05
#    --------------------- ------------------ 31.2/56.8 MB 6.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 31.7/56.8 MB 6.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 32.0/56.8 MB 6.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 32.3/56.8 MB 6.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 32.7/56.8 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 33.1/56.8 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 33.5/56.8 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 33.8/56.8 MB 6.6 MB/s eta 0:00:04
#    ------------------------ --------------- 34.2/56.8 MB 6.7 MB/s eta 0:00:04
#    ------------------------ --------------- 34.6/56.8 MB 6.8 MB/s eta 0:00:04
#    ------------------------ --------------- 34.6/56.8 MB 6.8 MB/s eta 0:00:04
#    ------------------------ --------------- 34.6/56.8 MB 6.8 MB/s eta 0:00:04
#    ------------------------ --------------- 34.6/56.8 MB 6.8 MB/s eta 0:00:04
#    ------------------------ --------------- 34.9/56.8 MB 6.0 MB/s eta 0:00:04
#    ------------------------ --------------- 35.3/56.8 MB 6.2 MB/s eta 0:00:04
#    ------------------------- -------------- 35.7/56.8 MB 6.1 MB/s eta 0:00:04
#    ------------------------- -------------- 36.2/56.8 MB 6.2 MB/s eta 0:00:04
#    ------------------------- -------------- 36.6/56.8 MB 6.9 MB/s eta 0:00:03
#    -------------------------- ------------- 37.0/56.8 MB 7.0 MB/s eta 0:00:03
#    -------------------------- ------------- 37.5/56.8 MB 7.1 MB/s eta 0:00:03
#    -------------------------- ------------- 37.9/56.8 MB 7.3 MB/s eta 0:00:03
#    -------------------------- ------------- 38.3/56.8 MB 7.4 MB/s eta 0:00:03
#    --------------------------- ------------ 38.7/56.8 MB 7.4 MB/s eta 0:00:03
#    --------------------------- ------------ 38.9/56.8 MB 7.4 MB/s eta 0:00:03
#    --------------------------- ------------ 39.2/56.8 MB 7.3 MB/s eta 0:00:03
#    --------------------------- ------------ 39.5/56.8 MB 7.2 MB/s eta 0:00:03
#    --------------------------- ------------ 39.7/56.8 MB 7.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 40.0/56.8 MB 7.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 40.3/56.8 MB 7.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 40.6/56.8 MB 7.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 41.0/56.8 MB 7.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 41.3/56.8 MB 7.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 41.7/56.8 MB 7.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 42.0/56.8 MB 7.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 42.4/56.8 MB 7.0 MB/s eta 0:00:03
#    ------------------------------ --------- 42.7/56.8 MB 7.0 MB/s eta 0:00:03
#    ------------------------------ --------- 43.1/56.8 MB 7.0 MB/s eta 0:00:02
#    ------------------------------ --------- 43.4/56.8 MB 6.9 MB/s eta 0:00:02
#    ------------------------------ --------- 43.7/56.8 MB 6.9 MB/s eta 0:00:02
#    ------------------------------- -------- 44.1/56.8 MB 6.9 MB/s eta 0:00:02
#    ------------------------------- -------- 44.3/56.8 MB 6.8 MB/s eta 0:00:02
#    ------------------------------- -------- 44.7/56.8 MB 6.8 MB/s eta 0:00:02
#    ------------------------------- -------- 44.9/56.8 MB 7.4 MB/s eta 0:00:02
#    ------------------------------- -------- 45.1/56.8 MB 7.4 MB/s eta 0:00:02
#    ------------------------------- -------- 45.4/56.8 MB 7.3 MB/s eta 0:00:02
#    -------------------------------- ------- 45.6/56.8 MB 7.1 MB/s eta 0:00:02
#    -------------------------------- ------- 45.8/56.8 MB 7.0 MB/s eta 0:00:02
#    -------------------------------- ------- 46.0/56.8 MB 6.9 MB/s eta 0:00:02
#    -------------------------------- ------- 46.2/56.8 MB 6.7 MB/s eta 0:00:02
#    -------------------------------- ------- 46.4/56.8 MB 6.7 MB/s eta 0:00:02
#    -------------------------------- ------- 46.7/56.8 MB 6.6 MB/s eta 0:00:02
#    --------------------------------- ------ 47.0/56.8 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 47.4/56.8 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 47.7/56.8 MB 6.4 MB/s eta 0:00:02
#    --------------------------------- ------ 48.0/56.8 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 48.3/56.8 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 48.7/56.8 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 49.1/56.8 MB 6.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 49.6/56.8 MB 6.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 49.9/56.8 MB 6.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 50.3/56.8 MB 6.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 50.6/56.8 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 50.9/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.3/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.6/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.9/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 52.3/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 52.7/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 53.0/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 53.4/56.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 53.5/56.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 53.6/56.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 54.1/56.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 54.3/56.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 54.6/56.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 54.8/56.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 55.0/56.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 55.4/56.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  55.7/56.8 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  56.1/56.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  56.5/56.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  56.8/56.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  56.8/56.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  56.8/56.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 56.8/56.8 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBRegressor

# Train on daily-level features
shap_model = XGBRegressor(
    n_estimators=100,
    max_depth=4,
    learning_rate=0.1,
    random_state=42
)
shap_model.fit(X_train_interpretable, y_train[:X_train_interpretable.shape[0]])
import shap

# Use the training set as background
explainer = shap.Explainer(shap_model, X_train_interpretable, feature_names=feature_names)
shap_values = explainer(X_test_interpretable)
# Bar plot: shows mean absolute SHAP values for features
shap.summary_plot(shap_values, X_test_interpretable, feature_names=feature_names, plot_type="bar")

# %%
# Structured features
struct_feat_names = list(X_train_struct.columns)  # e.g., ['failures_count', 'total_count']

# Word features — from vectorizer
word_feat_names = vectorizer.get_feature_names_out()  # length should be 105 if 107 total

# Combine
feature_names = struct_feat_names + list(word_feat_names)

# Verify
assert len(feature_names) == X_test_interpretable.shape[1]  # should pass

# %%
# Convert X_test_interpretable (list of arrays) to proper 2D numpy array
X_test_interpretable_np = np.array([np.array(row).flatten() for row in X_test_interpretable])

print("Shape:", X_test_interpretable_np.shape)  # should be (380, 107)
# Out:
# Shape: (380, 107)

# %%
import pandas as pd
import shap
shap.initjs()

# Pick first instance
instance_idx = 95
features_instance = pd.Series(X_test_interpretable_np[instance_idx], index=feature_names)

# Force plot
shap.force_plot(
    base_value=shap_values.base_values[instance_idx],
    shap_values=shap_values.values[instance_idx],
    features=features_instance
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iKT8A8HBHRTYQM6KDPVG6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 3.4484072878020062, "outValue": 3.5390231224242643, "link": "identity", "featureNames": ["failures_count", "total_count", "failures_lag1", "failures_ratio", "failures_roll_mean", "failures_roll_std", "failures_delta", "app", "not", "good", "capitec", "bank", "use", "new", "easy", "time", "work", "account", "keep", "excellent", "phone", "no", "great", "problem", "want", "banking", "even", "best", "open", "working", "old", "get", "need", "one", "please", "go", "money", "update", "like", "download", "make", "love", "say", "still", "trying", "service", "help", "data", "branch", "access", "log", "day", "ever", "thing", "saying", "always", "try", "using", "since", "really", "tried", "face", "error", "activate", "take", "issue", "number", "bad", "pin", "better", "know", "fix", "much", "everything", "back", "payment", "without", "give", "going", "happy", "install", "perfect", "could", "unable", "nice", "would", "login", "transaction", "never", "user", "experience", "must", "pay", "downloaded", "well", "option", "easier", "selfie", "scan", "card", "nothing", "able", "fast", "friendly", "simple", "every", "thank"], "features": {"0": {"effect": -0.1632294163505867, "value": 9.0}, "1": {"effect": 0.23428807611868252, "value": 28.0}, "2": {"effect": 0.003755891942564631, "value": 5.0}, "3": {"effect": -0.00864177047740668, "value": 0.5555554938271674}, "4": {"effect": 0.002030610509682447, "value": 6.0}, "5": {"effect": -0.0015651637238624971, "value": 4.582575694955852}, "6": {"effect": -0.01087234536476899, "value": 4.0}, "7": {"effect": 0.00027807747508632017, "value": 8.0}, "8": {"effect": 0.0014093219485948794, "value": 3.0}, "9": {"effect": 0.006462312942021526, "value": 4.0}, "10": {"effect": -0.0003087944723665714, "value": 4.0}, "11": {"effect": -0.003144829735974781, "value": 1.0}, "12": {"effect": -1.9946270622313023e-05, "value": 4.0}, "13": {"effect": 0.002491475624847226, "value": 0.0}, "14": {"effect": -0.006994060252327472, "value": 1.0}, "15": {"effect": 2.4162031477317213e-05, "value": 0.0}, "16": {"effect": 0.0003393635689280927, "value": 0.0}, "17": {"effect": 0.001300213888171129, "value": 0.0}, "18": {"effect": 0.007351634922379162, "value": 0.0}, "19": {"effect": 0.010063820180948823, "value": 2.0}, "20": {"effect": -0.0009192589507438242, "value": 0.0}, "21": {"effect": 4.126874831854366e-05, "value": 0.0}, "22": {"effect": -0.002544059492938686, "value": 2.0}, "23": {"effect": -0.0019345307594630867, "value": 0.0}, "24": {"effect": 0.0012575795594602823, "value": 3.0}, "25": {"effect": -0.0005993354637757875, "value": 0.0}, "26": {"effect": 0.00039892655215226116, "value": 0.0}, "27": {"effect": -0.008005911688669584, "value": 1.0}, "28": {"effect": -0.0017789747286587954, "value": 1.0}, "29": {"effect": 0.003051051642978564, "value": 0.0}, "30": {"effect": 0.0071170913920650496, "value": 0.0}, "31": {"effect": 0.00037199712940491733, "value": 0.0}, "32": {"effect": -0.0002491054218262434, "value": 2.0}, "33": {"effect": 0.001697483011521399, "value": 0.0}, "34": {"effect": 0.004624660017434508, "value": 1.0}, "35": {"effect": 0.00021657351520843805, "value": 1.0}, "36": {"effect": -0.0005745377679704689, "value": 1.0}, "37": {"effect": 0.0015298748388886453, "value": 2.0}, "38": {"effect": 5.636176239931956e-05, "value": 1.0}, "39": {"effect": 0.0005885079316794872, "value": 1.0}, "40": {"effect": -0.00018824741709977388, "value": 2.0}, "41": {"effect": -0.009687014080991502, "value": 0.0}, "43": {"effect": -0.012136558121419512, "value": 1.0}, "45": {"effect": 0.00019359646015800535, "value": 0.0}, "46": {"effect": 0.003814699057256803, "value": 1.0}, "47": {"effect": 0.0007561437849653885, "value": 1.0}, "48": {"effect": -0.0011806927347788587, "value": 1.0}, "49": {"effect": -0.0006304375024046749, "value": 0.0}, "50": {"effect": -0.0010212505212984979, "value": 1.0}, "51": {"effect": 0.002523691243841313, "value": 0. ...
#     document.getElementById('iKT8A8HBHRTYQM6KDPVG6')
#   );
# </script>

# %%
import pandas as pd
import shap
shap.initjs()

# Pick a day (instance index)
instance_idx = 95

# Get the full review(s) for this day
day_selected = daily_test['day'].iloc[instance_idx]
reviews_on_day = df_test[df_test['day'] == day_selected]['clean_content']

print(f"Reviews for {day_selected}:")
for r in reviews_on_day:
    print("-", r)

# Convert the interpretable X_test row to Series with feature names
features_instance = pd.Series(X_test_interpretable_np[instance_idx], index=feature_names)

# Force plot for this day
shap.force_plot(
    base_value=shap_values.base_values[instance_idx],
    shap_values=shap_values.values[instance_idx],
    features=features_instance
)
# Number of words features
num_words = X_words_test.shape[1]

# Get SHAP values for words only
shap_word_values = shap_values.values[instance_idx][:num_words]

# Get top 5 contributing words
top_word_idx = shap_word_values.argsort()[-5:][::-1]
top_words = [feature_names[i] for i in top_word_idx]
top_word_shap = shap_word_values[top_word_idx]

print("\nTop contributing words for this day:")
for w, val in zip(top_words, top_word_shap):
    print(f"{w}: {val:.3f}")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Reviews for 2024-03-22 00:00:00:
# - make app without visiting bank branch
# - capitec best
# - nice
# - good
# - lotto unavailable draw close
# - useless
# - fix bug app
# - bought rand telkom airtime via app deducted money not receive airtimeshowed error message despite still deducted rand please help
# - great
# - thanks
# - user capitec
# - usual capifec fails deliver need hey
# - trouble download totally kaak maan
# - excellent
# - patient client
# - fast easy use
# - make transfer easier
# - capitec app nice
# - johannesvandermerwe
# - want know check balance app
# - app shap update hell break loose sometimes log update
# - mama mkhutle
# - good app
# - good
# - great use capitec appso would like use future thank much
# - app not want appear menu want use go playstore playstore need data open appi not happy downloaded
# - excellent
# - good
#
# Top contributing words for this day:
# total_count: 0.234
# excellent: 0.010
# keep: 0.007
# old: 0.007
# good: 0.006

# %%
print(df_hover.columns.tolist())
# Out:
# ['Day', 'Actual_Score', 'Predicted_Score', 'failures_count', 'total_count']

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# -------------------------------
# 1️⃣ Prepare SHAP data
# -------------------------------
# shap_values: SHAP values from your model (X_test_interpretable)
shap_df = pd.DataFrame(shap_values.values, columns=feature_names)

# For each row, get top 5 absolute SHAP contributions
top_n = 5
top_shap_features = []
top_shap_values = []

for i in range(shap_df.shape[0]):
    row = shap_df.iloc[i]
    top_idx = row.abs().nlargest(top_n).index
    top_shap_features.append(top_idx.tolist())
    top_shap_values.append(row[top_idx].values.tolist())

# -------------------------------
# 2️⃣ Prepare existing features for hover
# -------------------------------
def get_customdata(df_set):
    columns = ['failures_count', 'total_count']  # only existing columns
    data = [df_set[col].fillna(0) for col in columns]
    return np.stack(data, axis=-1)

customdata_hover = get_customdata(df_hover)

# -------------------------------
# 3️⃣ Build hovertemplate
# -------------------------------
hover_template = (
    "Date: %{x}<br>"
    "Score: %{y:.2f}<br>"
    "Failures Count: %{customdata[0]:.0f}<br>"
    "Total Count: %{customdata[1]:.0f}<br>"
    "<b>Top SHAP Features:</b><br>"
    "%{text}<extra></extra>"
)

# -------------------------------
# 4️⃣ Build Plotly Figure
# -------------------------------
fig = go.Figure()

for y_data, name, color in zip(
    [df_hover['Actual_Score'], df_hover['Predicted_Score']],
    ['Actual Score', 'Predicted Score'],
    ['blue', 'red']
):
    # Prepare SHAP text for hover
    shap_text = [
        "<br>".join([f"{f}: {v:.3f}" for f, v in zip(top_shap_features[i], top_shap_values[i])])
        for i in range(len(y_data))
    ]
    
    fig.add_trace(go.Scatter(
        x=df_hover['Day'],
        y=y_data,
        mode='lines+markers',
        name=name,
        line=dict(color=color, width=2),
        customdata=customdata_hover,
        text=shap_text,
        hovertemplate=hover_template
    ))

# -------------------------------
# 5️⃣ Add Risk Zones and Threshold
# -------------------------------
threshold = 3.0
df_hover['High_Risk'] = df_hover['Predicted_Score'] < threshold

fig.add_hline(y=threshold, line=dict(color="orange", width=2, dash="dash"),
              annotation_text=f"Risk Threshold ({threshold})", annotation_position="bottom right")

def add_risk_zones(fig, df_set):
    days = pd.to_datetime(df_set['Day'])
    high_risk = df_set['High_Risk'].values
    start = None
    for i in range(len(high_risk)):
        if high_risk[i] and start is None:
            start = days.iloc[i]
        elif not high_risk[i] and start is not None:
            end = days.iloc[i]
            fig.add_vrect(x0=start, x1=end, fillcolor="red", opacity=0.2, layer="below", line_width=0)
            start = None
    if start is not None:
        fig.add_vrect(x0=start, x1=days.iloc[-1]+pd.Timedelta(days=1), fillcolor="red", opacity=0.2, layer="below", line_width=0)

add_risk_zones(fig, df_hover)

# -------------------------------
# 6️⃣ Layout
# -------------------------------
fig.update_layout(
    title='Time Series with Top SHAP Feature Contributions',
    xaxis_title='Date',
    yaxis_title='Score',
    hovermode='x unified',
    template='plotly_white'
)

fig.show()

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# -------------------------------
# 1️⃣ Prepare SHAP data
# -------------------------------
shap_df = pd.DataFrame(shap_values.values, columns=feature_names)

# Top 5 SHAP contributions per row
top_n = 5
top_shap_features = []
top_shap_values = []

for i in range(shap_df.shape[0]):
    row = shap_df.iloc[i]
    top_idx = row.abs().nlargest(top_n).index
    top_shap_features.append(top_idx.tolist())
    top_shap_values.append(row[top_idx].values.tolist())

# -------------------------------
# 2️⃣ Prepare existing features for hover
# -------------------------------
def get_customdata(df_set):
    columns = ['failures_count', 'total_count']  # only existing columns
    data = [df_set[col].fillna(0) for col in columns]
    return np.stack(data, axis=-1)

customdata_hover = get_customdata(df_hover)

# -------------------------------
# 3️⃣ Build colored SHAP hover text
# -------------------------------
def shap_hover_text(top_feats, top_vals):
    text_list = []
    for feats, vals in zip(top_feats, top_vals):
        lines = []
        for f, v in zip(feats, vals):
            color = "green" if v > 0 else "red"
            lines.append(f'<span style="color:{color}">{f}: {v:.3f}</span>')
        text_list.append("<br>".join(lines))
    return text_list

shap_text_colored = shap_hover_text(top_shap_features, top_shap_values)

# -------------------------------
# 4️⃣ Build hovertemplate
# -------------------------------
hover_template = (
    "Date: %{x}<br>"
    "Score: %{y:.2f}<br>"
    "Failures Count: %{customdata[0]:.0f}<br>"
    "Total Count: %{customdata[1]:.0f}<br>"
    "<b>Top SHAP Features:</b><br>"
    "%{text}<extra></extra>"
)

# -------------------------------
# 5️⃣ Build Plotly Figure
# -------------------------------
fig = go.Figure()

for y_data, name, color in zip(
    [df_hover['Actual_Score'], df_hover['Predicted_Score']],
    ['Actual Score', 'Predicted Score'],
    ['blue', 'red']
):
    fig.add_trace(go.Scatter(
        x=df_hover['Day'],
        y=y_data,
        mode='lines+markers',
        name=name,
        line=dict(color=color, width=2),
        customdata=customdata_hover,
        text=shap_text_colored,  # use colored SHAP text
        hovertemplate=hover_template
    ))

# -------------------------------
# 6️⃣ Add Risk Zones and Threshold
# -------------------------------
threshold = 3.0
df_hover['High_Risk'] = df_hover['Predicted_Score'] < threshold

fig.add_hline(y=threshold, line=dict(color="orange", width=2, dash="dash"),
              annotation_text=f"Risk Threshold ({threshold})", annotation_position="bottom right")

def add_risk_zones(fig, df_set):
    days = pd.to_datetime(df_set['Day'])
    high_risk = df_set['High_Risk'].values
    start = None
    for i in range(len(high_risk)):
        if high_risk[i] and start is None:
            start = days.iloc[i]
        elif not high_risk[i] and start is not None:
            end = days.iloc[i]
            fig.add_vrect(x0=start, x1=end, fillcolor="red", opacity=0.2, layer="below", line_width=0)
            start = None
    if start is not None:
        fig.add_vrect(x0=start, x1=days.iloc[-1]+pd.Timedelta(days=1), fillcolor="red", opacity=0.2, layer="below", line_width=0)

add_risk_zones(fig, df_hover)

# -------------------------------
# 7️⃣ Layout
# -------------------------------
fig.update_layout(
    title='Time Series with Top SHAP Feature Contributions (Color-coded)',
    xaxis_title='Date',
    yaxis_title='Score',
    hovermode='x unified',
    template='plotly_white'
)

fig.show()
